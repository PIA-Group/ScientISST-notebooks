# %% [markdown]
# # <div  style="color:#303030;font-family:'arial blACK', sans-serif,monospace; text-align: center; padding: 50px 0; vertical-align:middle;" > <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/Lightbulb.png?raw=true" style=" background:#00a0e4;border-radius:10px;width:150px;text-align:left; margin-left:10%"  /> <span style="position:relative; bottom:70px; margin-left:5%">  Meet your Biosignals with OpenSignals </span> </div>

# %% [markdown]
# ## <span style="color:#00a0e4;"> Keywords: </span>

# %% [markdown]
# ```Open Signals```, ```Biosignals```, ```Physiological Signals Acquisition```

# %% [markdown]
# # I. Introduction
# <br>
# <div style="width:100%; background:#00a0e4;font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# ## <div style="color:#00a0e4;"> 1. Background </div>

# %% [markdown]
# Biosignals have been extensively used in the healthcare and medical domains for more than 100 years, with the best known examples being perhaps Electrocardiography (ECG) and Electroencephalography (EEG). In this lesson we will perform a set of experiments using a real-world biomedical data acquisition system, understand the basic architecture of such systems, review typical setup procedures, and observe multiple signal sources in real-time.

# %% [markdown]
# ## <div style="color:#00a0e4;"> 2. Objectives</div>
#  * Understand the basic blocks of a data acquisition system
#  * Get acquainted with biosignal acquisition procedures
#  * Handling recorded data on a computing environment

# %% [markdown]
# ## <div style="color:#00a0e4;"> 3. Materials  </div>
#  * OpenSignals (r)evolution software
#  * 1x BITalino (r)evolution Board BT
#  * 1x 3.7V LiPo battery
#  * 1x 2-lead electrode cable
#  * 1x 3-lead electrode cable
#  * 5x Electrodes
#  * 1x Bluetooth adapter (optional)

# %% [markdown]
# # II. Experimental
# <br>
# <div style="width:100%; background:#00a0e4;font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# ### <div style="color:#00a0e4">   1.1. Setting up your BITalino (r)evolution  </div>
#    1. Connect the 3.7V LiPo battery on to the JST socket.
# <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/A.Signal_Acquisition_IMG/a001/Battery-Connection.png?raw=true" border="0" width=400>
#
#
#
#    2. Turn on the device (Figure 1(b)); a white LED should start fading.
#
# <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/A.Signal_Acquisition_IMG/a001/Power-On.png?raw=true" border="0" width=400>
#
#
#
#
#    3. Go to the Bluetooth device manager on your computer.
#    4. Search for BITalino devices in range.
#    5. Locate the device named BITalino-XX-XX, where XX-XX are the last four hexadecimal digits on the
#     sequence XX:XX:XX:XX:XX:XX labelled on the back of your board.
#    6. Pair your device with the computer using the PIN code 1234.
#
#
#
#
# ### <div style="color:#00a0e4">   1.2. Installing OpenSignals (r)evolution </div>
#
#    1. Access the SOFTWARE section on the BITalino website and choose the version that supports your operating system
#     (Windows/Mac OS), by clicking on its logo: http://www.bitalino.com/en/software
#
#    2. Open the software to confirm that it is working.
#
#    3. Hovering with the mouse pointer on each button shows a brief description of its function.
#
# ### <div style="color:#00a0e4">   1.3. Other useful tools </div>
#
# *   Install the Anaconda Python distribution that best suits your platform (Python 2.7 is recommended):
#
#   [https://www.anaconda.com/distribution/](https://www.anaconda.com/distribution/)
#
#   Get a better understanding of Python environments and toolboxes:
#
#     https://github.com/PIA-Group/ScientIST-notebooks/blob/master/C.Signal_Processing/C010%20Setup%20your%20Python%20workspace.ipynb
#
# * Install the BITalino Python API (recommended):
#
#   https://github.com/BITalinoWorld/revolution-python-api
#
# * Install OpenSignals (r)evolution Software:
#
#   http://bitalino.com/en/software
#
# * Prepare your device by connecting the battery (i.e. slide the battery connector onto the white socket on the BITalino block labelled as PWR)
#
# * Turn your device on by sliding the power button to the ON position; a white LED will start fading in / out, meaning that the device is in standby
#
#
#
# <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/A.Signal_Acquisition_IMG/a001/BITalino_cut.jpg?raw=true" border="0" width=700>

# %% [markdown]
# <div style="background:#62d321;font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; width:70%; margin:auto " >
#   <span style="font-size:20px;position:relative;color:white; "> Explore </span> <br>
#   <div style="background:#c5e8b0;font-size:12px">
#    Get familiar with the architecture of BITalino:
#       <a href="http://bitalino.com/datasheets/REVOLUTION_BITalino_Board_Kit_Datasheet.pdf"> datasheet </a>
# </div>

# %% [markdown]
# ## <div style="color:#00a0e4;"> 2. Acquisition </div>
#
#
#
# Once your BITalino is turned on, pair the device with your computer via the Bluetooth device manager using the PIN 1234 (this is a one-time process). Your device will be named BITalino-XX-XX, with XX-XX being the last four hex digits of your devices' MAC address.

# %% [markdown]
# <div style="background:#00bfc2;font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; width:70%; margin:auto " >
#   <span style="font-size:20px;position:relative;color:white; ">  Note </span> <br>
#   <div style="background:#9eddde;font-size:12px">
#      **IMPORTANT:** The MAC address is the sequence XX:XX:XX:XX:XX:XX found on the label on the back of the devices' BT block and / or on the back of the cardboard packaging where the device is shipped.
# </div>

# %% [markdown]
# The following steps should guide you through to a first glimpse of your signals in real-time:
#
# * Launch **OpenSignals (r)evolution**
#
# * Enable your device for acquisition by pressing the icon presented below on the main screen and clicking the box showing the MAC address of your device (this is a one-time process)

# %% [markdown]
# <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/A.Signal_Acquisition_IMG/a001/rec.png?raw=true"  alt="-" border="0" width=400>

# %% [markdown]
# <div style="background:#00bfc2;font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; width:70%; margin:auto " >
#   <span style="font-size:20px;position:relative;color:white; ">  Note </span> <br>
#   <div style="background:#9eddde;font-size:12px">
#      **IMPORTANT:** The ENABLE button needs to be blue.
# </div>

# %% [markdown]
# * You can proceed directly to record data, but you can also use this screen to configure the acquisition settings for your device (e.g. select the channels to be acquired, identify the type of sensor or change the sampling rate)
#
# * It is recommended that you review the sensor datasheets to obtain instructions regarding the typical electrode placement, sensor specifications and the transfer functions that can be used to convert the raw data into the correct physical units:
#
#   * [Electromiography (EMG)](http://bitalino.com/datasheets/REVOLUTION_EMG_Sensor_Datasheet.pdf)
#
#   * [Electrodermal Activity (EDA)](http://bitalino.com/datasheets/REVOLUTION_EDA_Sensor_Datasheet.pdf)
#   * [Electrocardiography (ECG)](http://bitalino.com/datasheets/REVOLUTION_ECG_Sensor_Datasheet.pdf)
#   * [Electroencephalography (EEG)](http://bitalino.com/datasheets/EEG_Sensor_Datasheet.pdf)
#   * [Accelerometry (ACC)](http://bitalino.com/datasheets/REVOLUTION_ACC_Sensor_Datasheet.pdf)
#   * [Optical Sensing (LUX)](http://bitalino.com/datasheets/REVOLUTION_LUX_Sensor_Datasheet.pdf)
#   * [Event Annotation (BTN)](http://bitalino.com/datasheets/REVOLUTION_BTN_Sensor_Datasheet.pdf)
# * **Record a signal** by pressing the red circle on the main menu of the software
#
# <img src="https://drive.google.com/uc?id=https://drive.google.com/file/d/18faxzjsyWi5rJ5oB5p2uje0IbcKWGVZt/view?usp=sharing?raw=true" border="0">
#
# <img src="https://drive.google.com/uc?id=1hRaA0h-b52q2vRYUP-TmGy-2uVvpPd2m?raw=true"  border="0">
#
# <img src="https://drive.google.com/uc?id=1iiO3BukE6Kt_u5632ffhXidSUS6hTG-L?raw=true" alt="Opensignals2" border="0">
#
# ### Testing your setup
# 1. Access the DEVICE MANAGER screen on the OpenSignals (r)evolution software
#
# <img src="https://drive.google.com/uc?id=1yGn389BXLqY7TRNXHESL6hnqgUTiPINR?raw=true" alt="-" border="0" width="300px">
#
#
#
# 2. Click on your device and confirm that it is enabled for data acquisition (ENABLE button highlighted in blue)
#
# <img src="https://drive.google.com/uc?id=148g3OCEE9SAJW33XfBbMF6GDVRKJbHrk?raw=true" alt="-" border="0" width="300px">
#
#
# 3. Press the RECORD icon to start a data acquisition session
#
# <img src="https://drive.google.com/uc?id=1ybhJ2WFx2iN63ZwrY5PzhO0YnBmQfWMr?raw=true" alt="-" border="0" width="300px">
#
#
# 4. The white LED on your device should switch from fading to blinking (indicating that the device is streaming data), and the acquisition time should be running on screen
#
# <img src="https://drive.google.com/uc?id=1EC0rQAObMHs9X2RcWAj89JDgnLtz0WnF?raw=true" alt="-" border="0" width="300px">

# %% [markdown]
# ## <div style="color:#00a0e4;">  3. Opening Recorded Data in Python </div>
#
# Locate a recording on your hard drive; for your convenience, we provide the [SampleACC.txt](https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/SampleACC.txt) file with a snippet of Accelerometry (ACC) data.
#
# You can make a simple experiment using the Python script below.

# %%
from pylab import *

data = loadtxt("SampleACC.txt")

plot(data[:,5])
show()

# %% [markdown]
# This code uses the function [loadtxt](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.loadtxt.html) (in this case made available through the PyLab module), to load the recorded data onto a variable in your program and display it in a graphic:

# %%
# !git clone https://github.com/BITalinoWorld/python-lab-guides >/dev/null 2>&1
! pip install mpld3 >/dev/null 2>&1

# %%
! cd python-lab-guides  >/dev/null 2>&1

# %%
from pylab import *
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

data = loadtxt("BITalino Hands-on/SampleACC.txt")

title('Accelerometry (ACC) data Sample')
plot(data[:,5],color="#00a0e4")

# %% [markdown]
# # III. Explore
# <br>
# <div style="width:100%; background:#00a0e4;font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# ## <div style="color:#00a0e4;">  1. Quiz  </div>
#
# 1. Draw a block diagram that shows the information flow and different stages between the body and the PC in a biosignal acquisition system.
#
# 2. Show a screenshot with Accelerometer (ACC) data for one of the repetitions executed in II.2. What do you interpret from this data?
#
# 3. As highlighted in the introductory segment of II.2., only one axis is connected by default. Which axis is it? Explain how you reached your conclusion.
#
# 4. Show a screenshot of a relevant portion of Electromyography (EMG) data within the experiment proposed on II.3. Does this signal correspond to what you expected? Why?
#
# 5. To the best of your knowledge, which noise sources can affect measurements made with bioelectrical sensors?

# %% [markdown]
# <div style="height:100px; background:white;border-radius:10px;text-align:center">
#
# <a> <img src="https://drive.google.com/uc?id=1tk6OaIBwLA9EMM1B-InUgBXPW1IjLzeD" alt="it" style=" bottom: 0; width:250px;
#     display: inline;
#     left: 250px;
#     position: absolute;"/> </a>
# <img src="https://drive.google.com/uc?id=1Mz7_sMoQn_cjNZFWQIMUqCWUm-t4Byd5"
#          alt="alternate text"
#          style="position: relative;   width:250px; float: left;
#     position: absolute;
#     display: inline;
#     bottom: 0;
#     right: 100;"/>
# </div>

# %% [markdown]
# <div style="width: 100%; ">
# <div style="background:#00a0e4;color:white;font-family:'arial', monospace; text-align: center; padding: 50px 0; border-radius:10px; height:10px; width:100%; float:left " >
# <span style="font-size:12px;position:relative; top:-25px">  Please provide us your feedback <span style="font-size:14px;position:relative;COLOR:WHITE"> <a href="https://forms.gle/C8TdLQUAS9r8BNJM8">here</a>.</span></span>
# <br>
# <span style="font-size:17px;position:relative; top:-20px">  Suggestions are welcome! </span>
# </div>

# %% [markdown]
# ```Contributors: Prof. Hugo Silva; Joana Pinto```
