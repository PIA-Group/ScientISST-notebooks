# %% [markdown]
#  # <div  style="color:#303030;font-family:'arial blACK', sans-serif,monospace; text-align: center; padding: 50px 0; vertical-align:middle;" > <img src="https://www.nicepng.com/png/full/204-2043038_white-lightbulb-icon-light-bulb-icon-white.png" style=" background:#00a0e4;border-radius:10px;width:150px;text-align:left; margin-left:10%"  /> <span style="position:relative; bottom:70px; margin-left:5%">    Frequency response </span> </div>

# %% [markdown]
# ## <span style="color:#00a0e4;"> Keywords: </span>

# %% [markdown]
# ```Electronic components```, ```Instrumentation```, ```Passive Circuits```

# %% [markdown]
# # I. Introduction
# <br>
# <div class="title"style="width:100%; background:#00a0e4;font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# ## <div style="color:#00a0e4"> 1. Background </div>

# %% [markdown]
# This session will comprise an introduction to the typical electronic equipment and instrumentation in a laboratory.

# %% [markdown]
# ## <div style="color:#00a0e4"> 2. Objectives</div>
# * Introducing the typical
# electronic laboratory
# equipment composed by
# cables, breadboards,
# electronic components
# (resistors, capacitors,
# transistors, etc)
# * Become familiar with the
# workbench
# instrumentation

# %% [markdown]
# ## <div style="color:#00a0e4"> 3. Materials</div>
# * 1x Multimeter
# * 1x Power supply
# * 1x Function generator
# * 1x Oscilloscope
# * 1x Breadboard
# * 1x 1kOhm resistor
# * 1x 10kOhm resistor
# * 1x 100nF capacitor
# * Jumper wires
# * Instrumentation cables

# %% [markdown]
# # II. Experimental
# <br>
# <div style="width:100%; background:#00a0e4;color:#282828;font-family:'arial black'; text-align: center; padding: 7px 0; border-radius: 5px 50px; margin-top:-15px" > </div>

# %% [markdown]
# ### <div style="color:#00a0e4">  1. Passive RC Circuit </div>

# %% [markdown]
# Consider the following Passive RC circuit:
#
# <img src="https://i.ibb.co/CbHSTJm/Screenshot-2020-10-13-at-15-41-49.png" width="500" border="0">

# %% [markdown]
# 1. Derive the transfer function of the circuit, G(s)=V0(s)/Vi(s)
# and the frequency response, H(ω). What type of filter is this
# circuit? Characterise it according the following parameters:<br>
#         a. DC gain<br>
#         b. -3dB cut-off frequency<br>
#         c. High frequency asymptotic decay slope.
#
# 2. Using the function generator apply 1 Vpp sine waves of
# different frequencies to the input of the circuit, vi, and
# measure, using the oscilloscope, the magnitude of v0. Register
# the results in Table 1. Select the range and number of
# measures according the results obtained in 1).
# <br><br>
# 3. Display these results in the following semi-log plot in
# dBs (20log(v0/vi)).
#
#     <img src="https://i.ibb.co/WPJHWhd/Screenshot-2020-10-13-at-15-54-06.png" alt="Screenshot-2020-10-13-at-15-54-06" border="0">
# <br><br>
# 4. Draw the asymptotic frequency response, derived from the transfer function obtained in 1), over the experimental points followingly represented.
#     <img src="https://i.ibb.co/2YsHnWL/Screenshot-2020-10-13-at-15-54-26.png" alt="Screenshot-2020-10-13-at-15-54-26" border="0">
# <br><br>
# 5. Apply a sinus wave to the input, vi=sin(2πf), and visualize vi
# and vo in XY mode in the oscilloscope. Sweep the frequency
# at the function generator. Comment what you observe and
# make a correlation with the frequency response obtained in
# 4).<br><br>
# 6. Simulate the circuit with the online “PartSim”, NI
# Multisim Live, or LT Spice simulator (you choose) and
# compare with the results you obtained experimentally.

# %% [markdown]
# # III. Explore
# <br>
# <div class='h1'  style="width:100%; background:#00a0e4;color:#282828;font-family:'arial black'; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" > </div>

# %% [markdown]
# ### <div style="color:#00a0e4">  1. Final Notes  </div>

# %% [markdown]
# <div style="height:115px; background:white;border-radius:10px;text-align:center">
#
# <img src="https://www.lx.it.pt/~asmc/predict/images/IT.png" alt="it" style="position: relative; margin-left: 10px; bottom:-55px;max-width:150px;height:auto;"/>
# <img src="https://cqe.tecnico.ulisboa.pt/files/files/logos/IST_A_RGB_POS.png"
#          alt="alternate text"
#          style="position: relative; margin-left: 10px;  bottom:-50px; width:150px;height:auto;"/>
# </div>

# %% [markdown]
# <div style="width: 100%; ">
# <div style="background:#00a0e4;color:white;font-family:'arial', monospace; text-align: center; padding: 50px 0; border-radius:10px; height:10px; width:100%; float:left " >
# <span style="font-size:12px;position:relative; top:-25px">  Please provide us your feedback <span style="font-size:14px;position:relative;COLOR:WHITE"> [here](https://forms.gle/C8TdLQUAS9r8BNJM8)</span>.</span>
# <br>
# <span style="font-size:17px;position:relative; top:-20px">  Suggestions are welcome! </span>
# </div>

# %% [markdown]
# ```Contributors: Prof. João Miguel Sanches; Prof. Hugo Plácido da Silva; Joana Pinto```
