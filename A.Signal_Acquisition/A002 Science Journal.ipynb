# %% [markdown]
# # <div  style="color:#303030;font-family:'arial blACK', sans-serif,monospace; text-align: center; padding: 50px 0; vertical-align:middle;" > <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/Lightbulb.png?raw=true" style=" background:#00a0e4;border-radius:10px;width:150px;text-align:left; margin-left:10%"  /> <span style="position:relative; bottom:70px; margin-left:5%"> Getting Started with <br> Google Science Journal (GSJ) </span> </div>

# %% [markdown]
# ## <span style="color:#00a0e4;"> Keywords: </span>

# %% [markdown]
# ```Experimental Journal```, ```Mobile Devices```, ```Data Acquisition```

# %% [markdown]
# # I. Introduction
# <br>
# <div style="width:100%; background:#00a0e4;font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# ## <div style="color:#00a0e4;"> 1. Background </div>

# %% [markdown]
# Google Science Journal (GSJ) is an App designed for students. It is able to transforma a phone, tablet, and Chromebook into a science notebook that encourages students to explore their world.
#
# GSJ allows students to measure their experiment results, take quality photos and make annotations throughout their experiments. Device sensors can be used for data acquisition, e.g. to measure light, sound, or movements.

# %% [markdown]
# <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/A.Signal_Acquisition_IMG/a002/science_journal_icon.png?raw=true" align="center" width="200"/>

# %% [markdown]
# ## <div style="color:#00a0e4;"> 2. Objectives</div>
#  * Understanding the main features provided by the GSJ App
#  * Performing an experiment using the methodology provided
#  * Sharing the recorded data for potential post-processing

# %% [markdown]
# ## <div style="color:#00a0e4;"> 3. Materials  </div>
#  * Mobile Phone
#  * GSJ App

# %% [markdown]
# # II. Experimental
# <br>
# <div style="width:100%; background:#00a0e4;font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# ## <div style="color:#00a0e4;">  0. Install the App </div>

# %% [markdown]
# It is available in both Android and iOS platforms.
#
# <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/A.Signal_Acquisition_IMG/a002/google-play-app-store-badges.jpg?raw=true"  width=200px/>

# %% [markdown]
# ## <div style="color:#00a0e4;">  1. Getting Started </div>

# %% [markdown]
# 1. Locate and launch the GSJ app; you can sign in with your Google account or proceed without signing in. <img src="attachment:sciencejournal.png" width="400"/>
#
# 2. On the GSJ app home screen (next figure, left) a library is shown with the history of experiments previously created, ordered by date of last edit; before any further experiments are created, only the “Welcome to Science Journal” entry appears.
# 3. Create a new experiment using the button (+).
# 4. A journal annotation screen appears (next figure, right)!

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1h-8Un5lD8trEbdDt8UaCwlptzpbZcs_-?raw=true" align="left" width="200"/> <img src="https://drive.google.com/uc?id=1QDkHxXe5rO34M5ffpzjcL5eJw65ttAuK?raw=true" width="200"/>

# %% [markdown]
# ## <div style="color:#00a0e4;">  2. Creating a Basic Journal </div>

# %% [markdown]
# 1. Access the journal settings screen using the "pencil" button.
# 2. Define a title for your experiment.
# 3. Assign a cover photo to your experiment.
# 4. Save the new settings using the "check" button.
# 5. In the journal you can create observations using multiple formats; these will appear in the top of the screen.
# 6. Text observations can be written in the text pane that appears when the "comment" button is pressed and submitted to the journal pressing the "right arrow" button.
# 7. Photos and screenshots can also be added to the journal by pressing the "photo" button (to take a photo) or the "image" button (to choose from the gallery); in the later case the image is submitted to the journal pressing the "right arrow" button.

# %% [markdown]
# ## <div style="color:#00a0e4;">  3. Recording Sensor Data </div>

# %% [markdown]
# 1. In addition to textual and pictorial observations, GSJ also allows the recording of sensor data from internal sensors on your mobile device using the options available in
# 2. Select the Accelerometer X channel by pressing
# 3. Swipe sensor pane up to view chart (next figure, top right)!
# 4. Swipe up a second time to show the option for adding more channels (next figure, bottom left)!
# 5. Add the Accelerometer Y and Accelerometer Z channels by pressing
# 6. You can annotate the instant values of the observed channels by pressing the button
# 7. You can record a time series with data from the observed channels using the button

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1gG_di1KcnSFlpo4Xok1A0679_GLu1NGI" align="left" width="200"/> <img src="https://drive.google.com/uc?id=1vUJGkaoINaEgIlS1VCPL8I-8aE4cV-g9" width="200"/>

# %% [markdown]
# <img src="https://drive.google.com/uc?id=12X3gDH4FRsTPQK9fX_ONsxGD_77SVrbH" align="left" width="200"/><img src="https://drive.google.com/uc?id=1Ap9z_rYjQ7CIpC8wentBhSygJvRoKA1B" width="200"/>

# %% [markdown]
# ## <div style="color:#00a0e4;">  4. Sharing your Data </div>

# %% [markdown]
# 1. You can download the complete journal or share it (if you are using the GSJ with a Google account) using the options available through the menu on the main screen
# 2. To export recorded time series tap the graph with the recording you would like to export to access the reviewing screen (next figure, left), and follow the next steps
# 3. Use the buttons a n d to browse through the channels (next figure, right)!
# 4. You can slide through the timeline and add annotations using the “ADD NOTE TO TIMELINE” option (next figure, right)!
# 5. Data can be downloaded as Comma-Separated Values (CSV) through the corresponding option on the menu
# 6. If you are using the GSJ with a Google account, it will also be possible to share the recording directly to the Google Drive, by e-mail, and other methods
# 7. When exporting your data, enabling the “Relative time” option is recommended so that the timeline is zero based, otherwise time will be exported as Unix Timestamps

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1YlNw-JE3ZXhm5qPypXVEjHomkvoh2bZ1" align="left" width="300"/><img src="https://drive.google.com/uc?id=1RjfKNeyqCS1PjB2jd244ATjYyIjceIGO" align="center" width="300"/>

# %% [markdown]
# ## <div style="color:#00a0e4;">  5. Your First Experiment </div>

# %% [markdown]
# 1. Create and configure the settings for a new journal to document a motion data acquisition experiment, complete with an appropriate title and cover photo
# 2. Complement the following steps with suitable textual and pictorial annotations that can thoroughly describe the materials, experimental methods, and data collected
# 3. Add sensor observation cards to your journal for recording Accelerometer X, Accelerometer Y, Accelerometer Z and sound data; the later should be used for event “annotation”
# 4. Hold the phone in your hand, start recording the data, perform 10 repetitions of right arm elevation at 90o in the coronal plane, and stop the recording
# 5. Repeat the previous step for 180o elevations
# 6. Repeat step 4. for the sagittal plane
# 7. Repeat step 4. for the sagittal plane and 180o elevations
# 8. Share your science journal, a PDF report (only available on iOS), and data in CSV format with your lecturer

# %% [markdown]
# # III. Explore
# <br>
# <div style="width:100%; background:#00a0e4;font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# ## <div style="color:#00a0e4;">  1. Further Reading </div>
#
# For a thourough understanding of GSJ, consult <a> www.sciencejournal.withgoogle.com </a>.

# %% [markdown]
# <div style="height:100px; background:white;border-radius:10px;text-align:center">
#
# <a> <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/IT.png?raw=true" alt="it" style=" bottom: 0; width:250px;
#     display: inline;
#     left: 250px;
#     position: absolute;"/> </a>
# <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/X.Example_Files/Images/ist.png?raw=true"
#          alt="alternate text"
#          style="position: relative;   width:250px; float: left;
#     position: absolute;
#     display: inline;
#     bottom: 0;
#     right: 100;"/>
# </div>

# %% [markdown]
# <div style="width: 100%; ">
# <div style="background:#00a0e4;color:white;font-family:'arial', monospace; text-align: center; padding: 50px 0; border-radius:10px; height:10px; width:100%; float:left " >
# <span style="font-size:12px;position:relative; top:-25px">  Please provide us your feedback <span style="font-size:14px;position:relative;COLOR:WHITE"> <a href="https://forms.gle/C8TdLQUAS9r8BNJM8">here</a>.</span></span>
# <br>
# <span style="font-size:17px;position:relative; top:-20px">  Suggestions are welcome! </span>
# </div>

# %% [markdown]
# ```Contributors: Prof. Hugo Silva; Joana Pinto```
