# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
# <br>
# <br>
# <br>
#
#
# # <div style="text-align:center; font-size:50px; color: #3c3c3c">ScientIST </div>
# # <div style="text-align:center; width:70%; margin-left:15%; font-size:30px; color: #3c3c3c">Mobile Devices, Cloud Services and IoT as Pedagogical Support Tools</div>
# <br>
# <br>
#
# ### <div style="text-align:center; color: #3c3c3c"> Joana Pinto </div>
#
# #### <div style="text-align:center; color:#005288"> Projectos de Inovação Pedagógica 2019 | 1018P.05667.1.01 </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
#
# # <div style="text-align:center; font-size:44px; color: #3c3c3c">Team</div>
#
# ![team.PNG](attachment:team.PNG)
#
# <div style="font-size:14px;; color: #3c3c3c">
#  <span style="margin-left:1%; display: inline-block;width:16%;text-align:center;"> Prof. Ana Fred   </span>     <span style="display: inline-block;width:16%;text-align:center;">      Prof. Hugo Silva </span>     <span style="display: inline-block;width:16%;text-align:center;">            Patrícia Bota </span>     <span style="display: inline-block;width:16%;text-align:center;">    Mariana Abreu </span>     <span style="display: inline-block;width:17%;text-align:center;">    Francisco Melo </span>     <span style="display: inline-block;width:14%;text-align:center;">    Joana Pinto</span>
#     </div>
# <br>
# <br>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# <div style="width:100%;height:550px; border-radius: 15px 50px 30px;background:#ddeaf6;display: inline-block;text-align:center; vertical-align:middle;color: #3c3c3c;font-weight:bold"><br> <br>  <span style="width:50%;margin-left:5%; font-size:70px; text-align:center;"> <br><br>Motivation</span>   </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color: #3c3c3c"> Progress in Education Practices </div>
#
# <br>
#
# <div>
# <div style="margin-left:12%; width:24%;height:60px; border-radius: 15px 50px 30px;background:#00bfc2;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:14px"><br>Project-based Learning (PBL) </div>
#
# <div style="width:24%;height:60px; border-radius: 15px 50px 30px;background:#fada5e;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:14px"><br>Flipped  classroom  (FC) </div>
#
# <div style="width:24%;height:60px; border-radius: 15px 50px 30px;background:#fe9b29;display: inline-block;text-align:center; vertical-align:bottom;color:white;font-weight:bold;font-size:14px"><br> e-Learning </div>
# <br><br>
# <div style="margin-left:30%;width:40%;height:60px; border-radius: 15px 50px 30px;background:#62d321;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:14px"> <br> Distance Learning  </div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Google Science Journal</div>
#
# <div style="margin-left:20%;"> <img src="https://edtech4beginnerscom.files.wordpress.com/2017/04/scijournal.png" align="left" width="200"/><img src="https://agrinavia.com/wp-content/uploads/2017/07/app-store.png" width="220"/></div>
#
# <div style="text-align:center;font-weight:bold;align:center" >
# <a href="https://sciencejournal.withgoogle.com/"> Visit site </a> </div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Google Science Journal</div>
#
# <div style="margin-left:22%; width:24%; height:100px; border-radius: 15px 50px 30px;background:#00bfc2;display: inline-block;text-align:center; vertical-align:middle;color:white;margin-top:-40%; font-weight:bold; font-size:16px"> <br><br>Reporting Experimental Activities</div>
# <div style="margin-left:10%; display: inline-block;"> <img src="https://i.ibb.co/djjXv6C/histologia.png" align="left" width="155"/>
# </div>
# <br>
# <div style="margin-left:24%; width:20%; height:100px; border-radius: 15px 50px 30px;background:white; text-align:center; vertical-align:middle;color:#3c3c3c;margin-top:-12%; font-size:16px">  Example of the documenting functionality, during an Histology Practical class.</div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Google Science Journal</div>
#
# <div style="margin-left:24%;display: inline-block;"> <img src="https://i.ibb.co/PjY43q5/Screenshot-20200226-190036-com-google-android-apps-forscience-whistlepunk.jpg" align="left" width="140"/>
# </div>
# <div style="margin-left:12%; width:24%;height:100px; border-radius: 15px 50px 30px;background:#00bfc2;display: inline-block;text-align:center; vertical-align:middle;color:white; margin-top:-52%; font-weight:bold; font-size:16px"><br><br>Data Logging</div>
# <br>
# <div style="margin-left:55%; width:22%; height:100px; border-radius: 15px 50px 30px;background:white; text-align:center; vertical-align:middle;color:#3c3c3c;margin-top:-19%; font-size:16px">  Example from an Accelerometry data acquisition.</div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
#
# # <div style="text-align:center; font-size:44px; color: #3c3c3c">Arduino</div>
# <div style="margin-left:20%;display: inline-block;"> <img src="https://i.ibb.co/svhdJtg/Arduino.png" align="left" width="270"/>
# </div>
#
# <div style="margin-left:55%; width: 24%; height:100px; border-radius: 15px 50px 30px;background:white; text-align:center; vertical-align:middle;color:#3c3c3c;margin-top:-19%; font-size:16px">  Easily connect  external sensors.</div>
#
# <br>
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
#
# # <div style="text-align:center; font-size:44px; color: #3c3c3c">Jupyter Notebooks</div>
# <div style="margin-left:39%;">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/250px-Jupyter_logo.svg.png" width="170"/> </div>
#
# <div style="text-align:center;font-weight:bold;font-size:14px" >
# <a href="https://jupyter.org/"> Visit site </a> </div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
#
# # <div style="text-align:center; font-size:44px; color: #3c3c3c">Jupyter Notebooks</div>
#
# <div style="margin-left:10%;"> <img src="https://i.ibb.co/GxcpVPp/nb1.png" align="left" width="350"/> <img src="https://i.ibb.co/dGFhs1s/nb2.png" width="220"/>
#     </div>
# <div style="margin-left:15%;width:20%;height:30px; border-radius: 15px 50px 30px;background:#62d321;display: inline-block;text-align:center; vertical-align:middle;color:white;"> Text </div>
# <div style="margin-left:5%;width:20%;height:30px; border-radius: 15px 50px 30px;background:#62d321;display: inline-block;text-align:center; vertical-align:middle;color:white;"> Images  </div>
# <div style="margin-left:5%;width:20%;height:30px; border-radius: 15px 50px 30px;background:#62d321;display: inline-block;text-align:center; vertical-align:middle;color:white;"> Python code </div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
#
# # <div style="text-align:center; font-size:44px; color: #3c3c3c">Jupyter Notebooks - Integrations</div>
#
# <div style="margin-left:30%;">
#     <div style="margin-left:15%;">
# <img src="https://miro.medium.com/max/502/1*9Q1rcr_peQdnGMwOYDBFhw.png" width="130"/>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a8/Microsoft_Azure_Logo.svg/1024px-Microsoft_Azure_Logo.svg.png" width="130"/>
# </div>
# <img src="https://i.ibb.co/ryKT1Yn/github.png" width="300"/>
# </div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color: #3c3c3c"> Examples</div>
# <div style="margin-left:20%; width:20%;margin-right:10%; display: inline-block;">
#     <img src="https://jakevdp.github.io/PythonDataScienceHandbook/figures/PDSH-cover.png" width="150"/> </div>
#
# <div style="margin-left:10%; width:20%;margin-bottom:16px; display: inline-block;">  <img src="https://d2l.ai/_images/front.png"  width="150" />
# </div>
#
# <div style="margin-left:10%;width:40%;height:45px; border-radius: 15px 50px 30px;background:#fada5e;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:14px">Python Data Science Handbook in the form of free Jupyter notebooks.</div>
# <div style="width:40%;height:45px; border-radius: 15px 50px 30px;background:#fada5e;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:14px">Dive into Deep Learning <br>(D2L.ai)</div>
#
#
# <div style="text-align:center;display: inline-block;width:42%;margin-left:7%;font-size:14px; color:#3c3c3c">
# <div style="font-weight:bold; font-size:14px"> <a href="https://github.com/jakevdp/PythonDataScienceHandbook"> Visit Github repository </a> </div>
# </div>
#
#
# <div style="text-align:center;display: inline-block;width:42%;font-size:14px">
# <div style="font-weight:bold; font-size:14px"> <a href="https://github.com/d2l-ai/d2l-en"> Visit Github repository </a>
#  </div>
# </div>
#
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# <div style="width:100%;height:550px; border-radius: 15px 50px 30px;background:#ddeaf6;display: inline-block;text-align:center; vertical-align:middle;color: #3c3c3c;font-weight:bold"><br> <br>  <span style="width:50%;margin-left:5%; font-size:70px; text-align:center;"> <br><br>ScientIST Notebooks</span>   </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
# <br><br>
#
# <div style="margin-left:15%; width:70%;height:230px; border-radius: 15px 50px 30px;background:#00bfc2;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold"><br>  <br><br><span style="width:50%;margin-left:5%; font-size:20px">Building an online Notebooks repository that is flexible, replicable and scalable for several engineering fields </span>   </div>
#
# <br>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Distance Learning at IST</div>
#
#
# <div style="margin-left:22%; width:30%;display: inline-block;">  <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQE3ejcrlopGnSU7UzO6PnEuqX-CtIbRoO5QA&usqp=CAU"  width="70%" />
# </div>
# <div style="margin-bottom:7%; width:30%;display: inline-block;">  <img src="http://e-lab.ist.eu/rec.web/javax.faces.resource/elab_logo.png.faces?ln=images"  width="70%" />
# </div>
#
# <br>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Potential Contribution</div>
#
# <br>
# <div style="margin-left:5%; width:90%;height:120px; border-radius: 15px 50px 30px;background:#00bfc2;text-align:center; vertical-align:middle;color:white;font-weight:bold;"><br> <span style="width:50%;margin-left:5%; font-size:16px">Building an online Notebooks repository that is flexible, replicable <br> and scalable for several engineering fields </span> </div>
# <br>
#
# <div style="margin-left:15%;width:24%;height:50px; border-radius: 15px 50px 30px;background:#62d321;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:16px"> <br> Laboratory classes </div>
# <div style="width:24%;height:50px; border-radius: 15px 50px 30px;background:#fe9b29;display: inline-block;text-align:center; vertical-align:bottom;color:white;font-weight:bold;font-size:16px"> <br> Practical classes </div>
# <div style=" width:24%;height:50px; border-radius: 15px 50px 30px;background:#fada5e;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:16px"><br> Project-based Learning  </div>
#
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Content Organization</div>
#
#
# <div style="text-align:center;display: inline-block;width:42%;margin-left:7%;font-size:14px">
# <div style="font-weight:bold"> DBE | Unidades Curriculares  </div>
# Introdução à Engenharia Biomédica<br>
# Instrumentação e Aquisição de Sinais Biomédicos (IASB)<br>
# Projeto em Engenharia Biomédica<br>
# Machine Learning in Bioengineering (MLB)<br><br><br><br>
# </div>
#
# <div style="display: inline-block;">
#     <br>
# <div style="width:90%; background:#fada5e;font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; margin:auto;" ><span style="font-size:20px;position:relative;color:white; "> 1 - Signal Acquisition  </span></div>
# <div style="width:90%; background:white; height:5px;margin:auto;" > </div>
# <div style="width:90%;background:#00bfc2;font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; margin:auto; " > <span style="font-size:20px;position:relative;color:white; ">  2 - Signal Processing and Feature Extraction   </span> </div>
# <div style="width:90%; background:white; height:5px;margin:auto;" > </div>
# <div style="background:#62d321;font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; margin:auto; width:90% " >  <span style="font-size:20px;position:relative;color:white; "> 3 - Classification </span> </div>
# <div style="width:90%; background:white; height:5px;margin:auto;" > </div>
# <div style="background:#fe9b29;font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; margin:auto;width:90% " >  <span style="font-size:20px;position:relative;color:white; ">   4 - Applications </span></div>
# </div>
#
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c"> Use-Case </div>
#
# <div style="margin-left:15%;display: inline-block;">
# <img src="https://i.ibb.co/4jhhFQJ/usecase.png" width="270"/></div>
#
# <div style="margin-left:60%;width:30%;height:150px; border-radius: 15px 50px 30px;background:#62d321;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:16px;margin-top:-40%"> <br><br>  Application in the Course of <br>Machine Learning in Bioengineering </div>
#
#
# <div style="margin-left:40%;margin-top:-70px;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Workflow</div>
# <br>
# <br>
# <div style="margin-left:15%;width:25%;height:100px; border-radius: 15px 50px 30px;background:#00bfc2 ;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:16px"><br>  1 - Signal Acquisition: <br> <br>Science Journal <br> </div>
# <div style="width:25%;height:100px; border-radius: 15px 50px 30px;background:#62d321;display: inline-block;text-align:center; vertical-align:bottom;color:white;font-weight:bold;font-size:16px"> <br> 2 - Signal Processing and Feature Extraction: <br><br>  </div>
# <div style=" width:25%;height:100px; border-radius: 15px 50px 30px;background:#fada5e;display: inline-block;text-align:center; vertical-align:middle;color:white;font-weight:bold;font-size:16px"> <br> 3 - Classification: <br> <br> Activity Recognition <br> ScientIST <br>  </div>
#
# <br>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Content Extension</div>
#
#
# <br>
# <div style="margin-left:40%;width:24%;height:110px; border-radius: 15px 50px 30px;background:#fe9b29;display: inline-block;text-align:center; vertical-align:bottom;color:white;font-weight:bold;font-size:16px"> <br> <br> Template Notebook  </div> <br>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# <div style="width:100%;height:550px; border-radius: 15px 50px 30px;background:#ddeaf6;display: inline-block;text-align:center; vertical-align:middle;color: #3c3c3c;font-weight:bold"><br> <br>  <span style="width:50%;margin-left:5%; font-size:70px; text-align:center;"> <br><br>Expected Outcomes</span>   </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
#
# # <div style="text-align:center; font-size:44px; color:#3c3c3c">Expected Outcomes</div>
#
#
#
# <div style="margin-left:10%;text-align:center;display: inline-block;width:40%;margin-left:7%;font-size:14px; color:#3c3c3c">
# <div style="font-weight:bold; font-size:19px"> For students: </div>
# <br>
# • Facilitate access to content while in distance learning<br>
#
# • Minimize the dependency on access to facilities and specialized equipment <br>
#
# • Reinforce the relationships with the
# industry and research centres<br>
#
# </div>
#
#
# <div style="text-align:center;display: inline-block;margin-left:5%; width:40%;font-size:14px">
# <div style="font-weight:bold; font-size:19px"> <br>For professors:</div>
# <br>
# • Continue to expand conventional teaching
# paradigms with project-based learning<br>
#
# • Capacitate the students with soft skills
# geared towards innovation<br>
#
# • Use higher quality results to increase the
# impact within the community at large<br>
# </div>
#
# <div style="margin-left:40%;"><img src="https://i.ibb.co/xF5XQYs/logo-scient-IST.png" width="200"/> </div>

# %% [markdown]
# ![header.PNG](attachment:header.PNG)
#
# <br>
# <br>
# <br>
# <br>
#
#
# # <div style="text-align:center; font-size:50px; color: #3c3c3c">ScientIST </div>
# # <div style="text-align:center; width:70%; margin-left:15%; font-size:30px; color: #3c3c3c">Mobile Devices, Cloud Services and IoT as Pedagogical Support Tools</div>
# <br>
# <br>
#
# ### <div style="text-align:center; color: #3c3c3c"> Joana Pinto </div>
#
# #### <div style="text-align:center; color:#005288"> Projectos de Inovação Pedagógica 2019 | 1018P.05667.1.01 </div>
