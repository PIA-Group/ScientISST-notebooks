# %% [markdown]
#  # <div  style="color:#303030;font-family:'arial blACK', sans-serif,monospace; text-align: center; padding: 50px 0; vertical-align:middle;" > <img src="https://github.com/PIA-Group/ScientIST-notebooks/blob/master/_Resources/Images/Lightbulb.png?raw=true" style=" background:linear-gradient(to right,#FDC86E,#fbb144);border-radius:10px;width:150px;text-align:left; margin-left:10%"  /> <span style="position:relative; bottom:70px; margin-left:5%">    Template - Example </span> </div>

# %% [markdown]
# ## <span style="color:#FDC86E;"> Keywords: </span>

# %% [markdown]
# ```Keyword 1```, ```Keyword 2```, ```Keyword 3```

# %% [markdown]
# # I. Introduction
# <br>
# <div class="title"style="width:100%; background:linear-gradient(to right,#FDC86E,#fbb144);font-family:'arial black',monospace; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" >  </div>

# %% [markdown]
# This notebook provides an overview to the complete set of notebooks made available in this repository. Despite being grouped by category, these are independent an can be organized as most suits the purpose of the course.

# %% [markdown]
# ## <div style="color:#FDC86E"> 1. Background </div>

# %% [markdown]
# This section should briefly comprise the concepts, context, and motivation to introduce the topic of the lab.

# %% [markdown]
# ## <div style="color:#FDC86E"> 2. Objectives</div>
# * Objetive 1 ...
# * Objetive 2 ...
# * ...

# %% [markdown]
# ## <div style="color:#FDC86E"> 3. Materials (optional) </div>
# * Material 1 ...
# * Material 2 ...
# * ...

# %% [markdown]
# # II. Experimental
# <br>
# <div style="width:100%; background:linear-gradient(to right,#FDC86E,#fbb144);font-family:'arial black'; text-align: center; padding: 7px 0; border-radius: 5px 50px; margin-top:-15px" > </div>

# %% [markdown]
# This section should guide the students during their experimental procedure, and contain the most relevant content.

# %% [markdown]
# ## <div style="color:#FDC86E">  1. Requirements (optional) </div>

# %% [markdown]
# In this section, the libraries required should be installed and imported:

# %%
# !pip install [LIBRARYNAME] >/dev/null 2>&1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## <div style="color:#FDC86E">  2. Data Loading (optional) </div>

# %% [markdown]
# ## <div style="color:#FDC86E">   3. EXAMPLES (optional) </div>

# %% [markdown]
# ### <div style="color:#FDC86E">   3.1. Plot Example  </div>

# %% [markdown]
# The following color palette should be respected in case any plot or graphic is drawn:

# %%
color_palette=['#48ba57', '#fbb144', '#ef564b', '#726658', '#946db2', '#46bd96', '#f26451']

# %%
# to enable basic visualization tools troughout the whole notebook:
# !pip install mpld3 >/dev/null 2>&1
import mpld3 
 
# note: in case you are using subplots, this tool will not work. In those cells, please add the following command:
# mpld3.enable_notebook()

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s1 = 1 + np.sin(2 * np.pi * t)
s2 = 2 + np.sin(1.5 * np.pi * t)
s3 = 2 + np.sin(2 * np.pi * t)

# plot
plt.title('Title of the plot', {'size':20})
plt.xlabel('Time (s)')
plt.ylabel('Angle [º]')
plt.plot(t, s1, label='signal 1',  color=color_palette[0])
plt.plot(t, s2, label='signal 2', color=color_palette[1])
plt.plot(t, s3, label='signal 3', color=color_palette[2])
plt.legend()
plt.show()

# %% [markdown]
# ### <div style="color:#FDC86E">   3.2. Table Example  </div>

# %%
#---
import pandas as pd
import csv
#---

url = '../X.Example_Files/example-table.csv'
dados = pd.read_csv(url,  delimiter = ';')

dados
dados.style.set_table_styles([dict(selector="th", props=[("font-size", "125%"),("color", color_palette[0]),
                               ("text-align", "center")]), 
                             dict(selector="tr", props=[
                               ("text-align", "center")])])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a153f3cf3140> in <module>()
#       8
#       9 dados
# ---> 10 dados.style.set_table_styles([dict(selector="th", props=[("font-size", "125%"),("color", color_palette[0]),
#      11                                ("text-align", "center")]),
#      12                              dict(selector="tr", props=[
#
# NameError: name 'color_palette' is not defined

# %% [markdown]
# ### <div style="color:#FDC86E">   3.3. Referring to other notebooks/material - Example  </div>

# %% [markdown]
# Throughout the text, it might be useful to refer to another notebooks or material saved in the repository. <br>
# That can be used the following example format:  <br>
# [OpenSignals](../1.Signal_Acquisition/OpenSignals.ipynb) <br>
# [ScienceJournal](../1.Signal_Acquisition/ScienceJournal.ipynb)

# %% [markdown]
# ### <div style="color:#FDC86E">   3.4. Using sample of code in Python - Example  </div>

# %%
# use the "Code" cell type

# %% [markdown]
# ### <div style="color:#FDC86E">   3.5. Using sample of code from other languages - Example  </div>

# %% [markdown]
# Use the "Markdown" cell type
#
# ```java
#
# click twice to see example
# int n=1
#
# ```

# %% [markdown]
# ### <div style="color:#FDC86E">   3.6. Notes and Warnings - Example  </div>

# %% [markdown]
# <div style="background:linear-gradient(to right,#fbb144,#ffd08a);font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; width:70%; margin:auto " >
#   <span style="font-size:20px;position:relative;color:white; ">  Warning! </span> <br>
#   <div style="background:#ffd08a;font-size:12px">
#     The warning must be explained here...
#     </div>
# </div>

# %% [markdown]
# <div style="background:linear-gradient(to right,#48ba57,#9de3a6);font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; width:70%; margin:auto " >
#   <span style="font-size:20px;position:relative;color:white; ">  Note </span> <br>
#   <div style="background:#9de3a6;font-size:12px">
#     The note must be explained here...
# </div>
# </div>

# %% [markdown]
# <div style="background:linear-gradient(to right,#d0b3e6,#946db2);font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; width:70%; margin:auto " >
#   <span style="font-size:20px;position:relative;color:white; "> Explore </span> <br>
#   <div style="background:#d0b3e6;font-size:12px">
#     The explore more advice must be explained here...
# </div>
# </div>

# %% [markdown]
# <div style="background:linear-gradient(to right,#fbb144,#f26451);font-family:'arial', monospace; text-align: center; padding: 10px 0; border-radius:10px; width:70%; margin:auto " >
#   <span style="font-size:20px;position:relative;color:white; ">  Caution! </span> <br>
#   <div style="background:#fbb144;font-size:12px">
#     The caution must be explained here...
# </div>
# </div>

# %% [markdown]
# ## <div style="color:#FDC86E">   4. Another Experimental Section  </div>

# %% [markdown]
# ...

# %% [markdown]
# # III. Explore
# <br>
# <div class='h1'  style="width:100%; background:linear-gradient(to right,#FDC86E,#fbb144);font-family:'arial black'; text-align: center; padding: 7px 0; border-radius: 5px 50px;margin-top:-15px" > </div>

# %% [markdown]
# Remember ...

# %% [markdown]
# ### <div style="color:#FDC86E">  1. Final Notes (optional) </div>

# %% [markdown]
# ### <div style="color:#FDC86E">  2. Quiz (optional)  </div>

# %% [markdown]
# ### <div style="color:#FDC86E">  3. Further Reading  </div>

# %% [markdown]
# <div style="height:100px; background:white;border-radius:10px;text-align:center">
#
# <a> <img src="https://www.di.ubi.pt/~agomes/index_files/LogoIT.png" alt="it" style=" bottom: 0; width:250px;
#     display: inline;
#     left: 250px;
#     position: absolute;"/> </a>
# <img src="https://cqe.tecnico.ulisboa.pt/files/files/logos/IST_A_RGB_POS.png"
#          alt="alternate text"
#          style="position: relative;   width:250px; float: left;
#     position: absolute;
#     display: inline;
#     bottom: 0;
#     right: 100;"/>
# </div>

# %% [markdown]
# <div style="width: 100%; ">
# <div style="background:linear-gradient(to right,#FDC86E,#fbb144);color:white;font-family:'arial', monospace; text-align: center; padding: 50px 0; border-radius:10px; height:10px; width:100%; float:left " >
# <span style="font-size:12px;position:relative; top:-25px">  Please provide us your feedback <span style="font-size:14px;position:relative;COLOR:WHITE"> <a href="https://forms.gle/C8TdLQUAS9r8BNJM8">here</a>.</span></span>
# <br>
# <span style="font-size:17px;position:relative; top:-20px">  Suggestions are welcome! </span>
# </div>

# %% [markdown]
# ```Contributors: Prof. ; ```
